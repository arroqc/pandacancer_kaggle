# %%
import skimage.io
import matplotlib.pyplot as plt

# %%
tiff_image = skimage.io.imread('G:/Datasets/panda/train_images/0005f7aaab2800f6170c399693a96917.tiff', plugin='tifffile')

# %%
tiff_image.shape
# Out:
# (29440, 27648, 3)

# %%
plt.figure(figsize=(20,20))
plt.imshow(tiff_image[3000:8000, 3000:8000])
